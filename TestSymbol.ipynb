# %%
import cv2 as cv 
import numpy as np
import scipy
import PIL.Image
import math
import caffe
import time

import matplotlib
# %matplotlib inline
import pylab as plt
import sys
sys.path.append('../../practice_demo')

from symbol.resnext import *

# %%
resnext = get_symbol(5,18, ('3,300,300'))

# %%
mx.viz.plot_network(symbol=resnext)
